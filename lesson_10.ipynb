# %%
# %pip install pandas
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
# DEPRECATION: textract 1.6.4 has a non-standard dependency specifier extract-msg<=0.29.*. pip 24.0 will enforce this behaviour change. A possible replacement is to upgrade to a newer version of textract or contact the author to suggest that they release a version with a conforming dependency specifiers. Discussion can be found at https://github.com/pypa/pip/issues/12063

# %%
# Only works in Jupyter Notebook
pip install pandas
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
# DEPRECATION: textract 1.6.4 has a non-standard dependency specifier extract-msg<=0.29.*. pip 24.0 will enforce this behaviour change. A possible replacement is to upgrade to a newer version of textract or contact the author to suggest that they release a version with a conforming dependency specifiers. Discussion can be found at https://github.com/pypa/pip/issues/12063

# %%
import pandas as pd

# %%
df = pd.DataFrame(
   [ ['Jan',58,42,74,22,2.05],
    ['Feb',61,45,78,26,3.02],
    ['Mar',65,48,84,25,2.34],
    ['Apr',67,50,92,28,1.02],
    ['May',71,53,98,35,0.48],
    ['Jun',75,56,107,41,0.11],
    ['Jul',77,58,105,44,0.0],
    ['Aug',77,59,102,43,0.03],
    ['Sep',77,57,103,40,0.17],
    ['Oct',73,54,96,34,0.81],
    ['Nov',64,48,84,30,1.7],
    ['Dec',58,None,None,21,2.56],    
    ['Dec',58,42,73,21,2.56] ],
    columns = ['month','avg_high','avg_low','record_high','record_low','avg_precipitation'])

# %%
df
# Out:
#    month  avg_high  avg_low  record_high  record_low  avg_precipitation
# 0    Jan        58     42.0         74.0          22               2.05
# 1    Feb        61     45.0         78.0          26               3.02
# 2    Mar        65     48.0         84.0          25               2.34
# 3    Apr        67     50.0         92.0          28               1.02
# 4    May        71     53.0         98.0          35               0.48
# 5    Jun        75     56.0        107.0          41               0.11
# 6    Jul        77     58.0        105.0          44               0.00
# 7    Aug        77     59.0        102.0          43               0.03
# 8    Sep        77     57.0        103.0          40               0.17
# 9    Oct        73     54.0         96.0          34               0.81
# 10   Nov        64     48.0         84.0          30               1.70
# 11   Dec        58      NaN          NaN          21               2.56
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 13 entries, 0 to 12
# Data columns (total 6 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   month              13 non-null     object
#  1   avg_high           13 non-null     int64
#  2   avg_low            12 non-null     float64
#  3   record_high        12 non-null     float64
#  4   record_low         13 non-null     int64
#  5   avg_precipitation  13 non-null     float64
# dtypes: float64(3), int64(2), object(1)
# memory usage: 752.0+ bytes

# %%
df.describe()
# Out:
#         avg_high    avg_low  record_high  record_low  avg_precipitation
# count  13.000000  12.000000    12.000000   13.000000          13.000000
# mean   67.769231  51.000000    91.333333   31.538462           1.296154
# std     7.639305   6.060303    12.323911    8.501131           1.115210
# min    58.000000  42.000000    73.000000   21.000000           0.000000
# 25%    61.000000  47.250000    82.500000   25.000000           0.170000
# 50%    67.000000  51.500000    94.000000   30.000000           1.020000
# 75%    75.000000  56.250000   102.250000   40.000000           2.340000
# max    77.000000  59.000000   107.000000   44.000000           3.020000

# %%
df.head()
# Out:
#   month  avg_high  avg_low  record_high  record_low  avg_precipitation
# 0   Jan        58     42.0         74.0          22               2.05
# 1   Feb        61     45.0         78.0          26               3.02
# 2   Mar        65     48.0         84.0          25               2.34
# 3   Apr        67     50.0         92.0          28               1.02
# 4   May        71     53.0         98.0          35               0.48

# %%
df.head(3)
# Out:
#   month  avg_high  avg_low  record_high  record_low  avg_precipitation
# 0   Jan        58     42.0         74.0          22               2.05
# 1   Feb        61     45.0         78.0          26               3.02
# 2   Mar        65     48.0         84.0          25               2.34

# %%
df.tail(3)
# Out:
#    month  avg_high  avg_low  record_high  record_low  avg_precipitation
# 10   Nov        64     48.0         84.0          30               1.70
# 11   Dec        58      NaN          NaN          21               2.56
# 12   Dec        58     42.0         73.0          21               2.56

# %%
list(df.columns)
# Out:
# ['month',
#  'avg_high',
#  'avg_low',
#  'record_high',
#  'record_low',
#  'avg_precipitation']

# %%
df
# Out:
#    month  avg_high  avg_low  record_high  record_low  avg_precipitation
# 0    Jan        58     42.0         74.0          22               2.05
# 1    Feb        61     45.0         78.0          26               3.02
# 2    Mar        65     48.0         84.0          25               2.34
# 3    Apr        67     50.0         92.0          28               1.02
# 4    May        71     53.0         98.0          35               0.48
# 5    Jun        75     56.0        107.0          41               0.11
# 6    Jul        77     58.0        105.0          44               0.00
# 7    Aug        77     59.0        102.0          43               0.03
# 8    Sep        77     57.0        103.0          40               0.17
# 9    Oct        73     54.0         96.0          34               0.81
# 10   Nov        64     48.0         84.0          30               1.70
# 11   Dec        58      NaN          NaN          21               2.56
# ...

# %%
df.sort_values( 'record_high' )
# Out:
#    month  avg_high  avg_low  record_high  record_low  avg_precipitation
# 12   Dec        58     42.0         73.0          21               2.56
# 0    Jan        58     42.0         74.0          22               2.05
# 1    Feb        61     45.0         78.0          26               3.02
# 2    Mar        65     48.0         84.0          25               2.34
# 10   Nov        64     48.0         84.0          30               1.70
# 3    Apr        67     50.0         92.0          28               1.02
# 9    Oct        73     54.0         96.0          34               0.81
# 4    May        71     53.0         98.0          35               0.48
# 7    Aug        77     59.0        102.0          43               0.03
# 8    Sep        77     57.0        103.0          40               0.17
# 6    Jul        77     58.0        105.0          44               0.00
# 5    Jun        75     56.0        107.0          41               0.11
# ...

# %%
df.sort_values( ['record_high', 'avg_high' ] )
# Out:
#    month  avg_high  avg_low  record_high  record_low  avg_precipitation
# 12   Dec        58     42.0         73.0          21               2.56
# 0    Jan        58     42.0         74.0          22               2.05
# 1    Feb        61     45.0         78.0          26               3.02
# 10   Nov        64     48.0         84.0          30               1.70
# 2    Mar        65     48.0         84.0          25               2.34
# 3    Apr        67     50.0         92.0          28               1.02
# 9    Oct        73     54.0         96.0          34               0.81
# 4    May        71     53.0         98.0          35               0.48
# 7    Aug        77     59.0        102.0          43               0.03
# 8    Sep        77     57.0        103.0          40               0.17
# 6    Jul        77     58.0        105.0          44               0.00
# 5    Jun        75     56.0        107.0          41               0.11
# ...

# %%
df.sort_values( 'record_high', ascending=False )
# Out:
#    month  avg_high  avg_low  record_high  record_low  avg_precipitation
# 5    Jun        75     56.0        107.0          41               0.11
# 6    Jul        77     58.0        105.0          44               0.00
# 8    Sep        77     57.0        103.0          40               0.17
# 7    Aug        77     59.0        102.0          43               0.03
# 4    May        71     53.0         98.0          35               0.48
# 9    Oct        73     54.0         96.0          34               0.81
# 3    Apr        67     50.0         92.0          28               1.02
# 2    Mar        65     48.0         84.0          25               2.34
# 10   Nov        64     48.0         84.0          30               1.70
# 1    Feb        61     45.0         78.0          26               3.02
# 0    Jan        58     42.0         74.0          22               2.05
# 12   Dec        58     42.0         73.0          21               2.56
# ...

# %%
df.sort_values( ['record_high', 'avg_high' ], ascending=[False,False] )
# Out:
#    month  avg_high  avg_low  record_high  record_low  avg_precipitation
# 5    Jun        75     56.0        107.0          41               0.11
# 6    Jul        77     58.0        105.0          44               0.00
# 8    Sep        77     57.0        103.0          40               0.17
# 7    Aug        77     59.0        102.0          43               0.03
# 4    May        71     53.0         98.0          35               0.48
# 9    Oct        73     54.0         96.0          34               0.81
# 3    Apr        67     50.0         92.0          28               1.02
# 2    Mar        65     48.0         84.0          25               2.34
# 10   Nov        64     48.0         84.0          30               1.70
# 1    Feb        61     45.0         78.0          26               3.02
# 0    Jan        58     42.0         74.0          22               2.05
# 12   Dec        58     42.0         73.0          21               2.56
# ...

# %%
df.sort_values( ['record_high', 'avg_high' ], ascending=False )
# Out:
#    month  avg_high  avg_low  record_high  record_low  avg_precipitation
# 5    Jun        75     56.0        107.0          41               0.11
# 6    Jul        77     58.0        105.0          44               0.00
# 8    Sep        77     57.0        103.0          40               0.17
# 7    Aug        77     59.0        102.0          43               0.03
# 4    May        71     53.0         98.0          35               0.48
# 9    Oct        73     54.0         96.0          34               0.81
# 3    Apr        67     50.0         92.0          28               1.02
# 2    Mar        65     48.0         84.0          25               2.34
# 10   Nov        64     48.0         84.0          30               1.70
# 1    Feb        61     45.0         78.0          26               3.02
# 0    Jan        58     42.0         74.0          22               2.05
# 12   Dec        58     42.0         73.0          21               2.56
# ...

# %%
df
# Out:
#    month  avg_high  avg_low  record_high  record_low  avg_precipitation
# 0    Jan        58     42.0         74.0          22               2.05
# 1    Feb        61     45.0         78.0          26               3.02
# 2    Mar        65     48.0         84.0          25               2.34
# 3    Apr        67     50.0         92.0          28               1.02
# 4    May        71     53.0         98.0          35               0.48
# 5    Jun        75     56.0        107.0          41               0.11
# 6    Jul        77     58.0        105.0          44               0.00
# 7    Aug        77     59.0        102.0          43               0.03
# 8    Sep        77     57.0        103.0          40               0.17
# 9    Oct        73     54.0         96.0          34               0.81
# 10   Nov        64     48.0         84.0          30               1.70
# 11   Dec        58      NaN          NaN          21               2.56
# ...

# %%
print( type(df) )
# Out:
# <class 'pandas.core.frame.DataFrame'>

# %%
df['avg_precipitation_new'] = df['avg_precipitation'] * 1.1
df
# Out:
#    month  avg_high  avg_low  record_high  record_low  avg_precipitation  \
# 0    Jan        58     42.0         74.0          22               2.05
# 1    Feb        61     45.0         78.0          26               3.02
# 2    Mar        65     48.0         84.0          25               2.34
# 3    Apr        67     50.0         92.0          28               1.02
# 4    May        71     53.0         98.0          35               0.48
# 5    Jun        75     56.0        107.0          41               0.11
# 6    Jul        77     58.0        105.0          44               0.00
# 7    Aug        77     59.0        102.0          43               0.03
# 8    Sep        77     57.0        103.0          40               0.17
# 9    Oct        73     54.0         96.0          34               0.81
# 10   Nov        64     48.0         84.0          30               1.70
# 11   Dec        58      NaN          NaN          21               2.56
# ...

# %%
print( type( df['avg_precipitation_new'] ) )
# Out:
# <class 'pandas.core.series.Series'>

# %%
df['avg_precipitation_new']
# Out:
# 0     2.255
# 1     3.322
# 2     2.574
# 3     1.122
# 4     0.528
# 5     0.121
# 6     0.000
# 7     0.033
# 8     0.187
# 9     0.891
# 10    1.870
# 11    2.816
# 12    2.816
# Name: avg_precipitation_new, dtype: float64

# %%
df
# Out:
#    month  avg_high  avg_low  record_high  record_low  avg_precipitation  \
# 0    Jan        58     42.0         74.0          22               2.05
# 1    Feb        61     45.0         78.0          26               3.02
# 2    Mar        65     48.0         84.0          25               2.34
# 3    Apr        67     50.0         92.0          28               1.02
# 4    May        71     53.0         98.0          35               0.48
# 5    Jun        75     56.0        107.0          41               0.11
# 6    Jul        77     58.0        105.0          44               0.00
# 7    Aug        77     59.0        102.0          43               0.03
# 8    Sep        77     57.0        103.0          40               0.17
# 9    Oct        73     54.0         96.0          34               0.81
# 10   Nov        64     48.0         84.0          30               1.70
# 11   Dec        58      NaN          NaN          21               2.56
# ...

# %%
df.shape
# Out:
# (13, 7)

# %%
df['naujas'] = 1
df
# Out:
#    month  avg_high  avg_low  record_high  record_low  avg_precipitation  \
# 0    Jan        58     42.0         74.0          22               2.05
# 1    Feb        61     45.0         78.0          26               3.02
# 2    Mar        65     48.0         84.0          25               2.34
# 3    Apr        67     50.0         92.0          28               1.02
# 4    May        71     53.0         98.0          35               0.48
# 5    Jun        75     56.0        107.0          41               0.11
# 6    Jul        77     58.0        105.0          44               0.00
# 7    Aug        77     59.0        102.0          43               0.03
# 8    Sep        77     57.0        103.0          40               0.17
# 9    Oct        73     54.0         96.0          34               0.81
# 10   Nov        64     48.0         84.0          30               1.70
# 11   Dec        58      NaN          NaN          21               2.56
# ...

# %%
df.loc[ 5 ]
# Out:
# month                      Jun
# avg_high                    75
# avg_low                   56.0
# record_high              107.0
# record_low                  41
# avg_precipitation         0.11
# avg_precipitation_new    0.121
# naujas                       1
# Name: 5, dtype: object

# %%
df.loc[ 5:6 ] # inclusive
# Out:
#   month  avg_high  avg_low  record_high  record_low  avg_precipitation  \
# 5   Jun        75     56.0        107.0          41               0.11
# 6   Jul        77     58.0        105.0          44               0.00
#
#    avg_precipitation_new  naujas
# 5                  0.121       1
# 6                  0.000       1

# %%
[5,46,864,34,34,84,3][5:6]
# Out:
# [84]

# %%
df.loc[ 5:10 ]
# Out:
#    month  avg_high  avg_low  record_high  record_low  avg_precipitation  \
# 5    Jun        75     56.0        107.0          41               0.11
# 6    Jul        77     58.0        105.0          44               0.00
# 7    Aug        77     59.0        102.0          43               0.03
# 8    Sep        77     57.0        103.0          40               0.17
# 9    Oct        73     54.0         96.0          34               0.81
# 10   Nov        64     48.0         84.0          30               1.70
#
#     avg_precipitation_new  naujas
# 5                   0.121       1
# 6                   0.000       1
# 7                   0.033       1
# 8                   0.187       1
# 9                   0.891       1
# 10                  1.870       1

# %%
df_sorted = df.sort_values( 'record_high' )
df_sorted
# Out:
#    month  avg_high  avg_low  record_high  record_low  avg_precipitation  \
# 12   Dec        58     42.0         73.0          21               2.56
# 0    Jan        58     42.0         74.0          22               2.05
# 1    Feb        61     45.0         78.0          26               3.02
# 2    Mar        65     48.0         84.0          25               2.34
# 10   Nov        64     48.0         84.0          30               1.70
# 3    Apr        67     50.0         92.0          28               1.02
# 9    Oct        73     54.0         96.0          34               0.81
# 4    May        71     53.0         98.0          35               0.48
# 7    Aug        77     59.0        102.0          43               0.03
# 8    Sep        77     57.0        103.0          40               0.17
# 6    Jul        77     58.0        105.0          44               0.00
# 5    Jun        75     56.0        107.0          41               0.11
# ...

# %%
df_sorted.loc[ [4,5,6,7] ]
# Out:
#   month  avg_high  avg_low  record_high  record_low  avg_precipitation  \
# 4   May        71     53.0         98.0          35               0.48
# 5   Jun        75     56.0        107.0          41               0.11
# 6   Jul        77     58.0        105.0          44               0.00
# 7   Aug        77     59.0        102.0          43               0.03
#
#    avg_precipitation_new  naujas
# 4                  0.528       1
# 5                  0.121       1
# 6                  0.000       1
# 7                  0.033       1

# %%
df_sorted.loc[ [4,5,6,7], 'record_low' ] # .loc[ [indexes], [columns] ]
# Out:
# 4    35
# 5    41
# 6    44
# 7    43
# Name: record_low, dtype: int64

# %%
df_sorted.loc[ [4,5,6,7], ['record_low', 'avg_precipitation' ] ]
# Out:
#    record_low  avg_precipitation
# 4          35               0.48
# 5          41               0.11
# 6          44               0.00
# 7          43               0.03

# %%
df_sorted.loc[ :, ['record_low', 'avg_precipitation' ] ] # this is recommended
# df_sorted[ ['record_low', 'avg_precipitation' ] ] # same
# Out:
#     record_low  avg_precipitation
# 12          21               2.56
# 0           22               2.05
# 1           26               3.02
# 2           25               2.34
# 10          30               1.70
# 3           28               1.02
# 9           34               0.81
# 4           35               0.48
# 7           43               0.03
# 8           40               0.17
# 6           44               0.00
# 5           41               0.11
# 11          21               2.56

# %%
df_sorted
# Out:
#    month  avg_high  avg_low  record_high  record_low  avg_precipitation  \
# 12   Dec        58     42.0         73.0          21               2.56
# 0    Jan        58     42.0         74.0          22               2.05
# 1    Feb        61     45.0         78.0          26               3.02
# 2    Mar        65     48.0         84.0          25               2.34
# 10   Nov        64     48.0         84.0          30               1.70
# 3    Apr        67     50.0         92.0          28               1.02
# 9    Oct        73     54.0         96.0          34               0.81
# 4    May        71     53.0         98.0          35               0.48
# 7    Aug        77     59.0        102.0          43               0.03
# 8    Sep        77     57.0        103.0          40               0.17
# 6    Jul        77     58.0        105.0          44               0.00
# 5    Jun        75     56.0        107.0          41               0.11
# ...

# %%
df_sorted.iloc[ 0:3 ]
# Out:
#    month  avg_high  avg_low  record_high  record_low  avg_precipitation  \
# 12   Dec        58     42.0         73.0          21               2.56
# 0    Jan        58     42.0         74.0          22               2.05
# 1    Feb        61     45.0         78.0          26               3.02
#
#     avg_precipitation_new  naujas
# 12                  2.816       1
# 0                   2.255       1
# 1                   3.322       1

# %%
df_sorted.iloc[ 5 ]
# Out:
# month                      Apr
# avg_high                    67
# avg_low                   50.0
# record_high               92.0
# record_low                  28
# avg_precipitation         1.02
# avg_precipitation_new    1.122
# naujas                       1
# Name: 3, dtype: object

# %%
df_sorted.iloc[ [5,8,9] ]
# Out:
#   month  avg_high  avg_low  record_high  record_low  avg_precipitation  \
# 3   Apr        67     50.0         92.0          28               1.02
# 7   Aug        77     59.0        102.0          43               0.03
# 8   Sep        77     57.0        103.0          40               0.17
#
#    avg_precipitation_new  naujas
# 3                  1.122       1
# 7                  0.033       1
# 8                  0.187       1

# %%
df_indexed = df_sorted.set_index( 'month' )
df_indexed
# Out:
#        avg_high  avg_low  record_high  record_low  avg_precipitation  \
# month
# Dec          58     42.0         73.0          21               2.56
# Jan          58     42.0         74.0          22               2.05
# Feb          61     45.0         78.0          26               3.02
# Mar          65     48.0         84.0          25               2.34
# Nov          64     48.0         84.0          30               1.70
# Apr          67     50.0         92.0          28               1.02
# Oct          73     54.0         96.0          34               0.81
# May          71     53.0         98.0          35               0.48
# Aug          77     59.0        102.0          43               0.03
# Sep          77     57.0        103.0          40               0.17
# Jul          77     58.0        105.0          44               0.00
# Jun          75     56.0        107.0          41               0.11
# ...

# %%
df_indexed.loc['Aug']
# Out:
# avg_high                  77.000
# avg_low                   59.000
# record_high              102.000
# record_low                43.000
# avg_precipitation          0.030
# avg_precipitation_new      0.033
# naujas                     1.000
# Name: Aug, dtype: float64

# %%
df_indexed.loc['Dec']
# Out:
#        avg_high  avg_low  record_high  record_low  avg_precipitation  \
# month
# Dec          58     42.0         73.0          21               2.56
# Dec          58      NaN          NaN          21               2.56
#
#        avg_precipitation_new  naujas
# month
# Dec                    2.816       1
# Dec                    2.816       1

# %%
df_indexed.loc[ 5 ] # error
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File c:\Users\Robotux\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\core\indexes\base.py:3361, in Index.get_loc(self, key, method, tolerance)
#    3360 try:
# -> 3361     return self._engine.get_loc(casted_key)
#    3362 except KeyError as err:
#
# File c:\Users\Robotux\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\_libs\index.pyx:76, in pandas._libs.index.IndexEngine.get_loc()
#
# File c:\Users\Robotux\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\_libs\index.pyx:103, in pandas._libs.index.IndexEngine.get_loc()
#
# File c:\Users\Robotux\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\_libs\index.pyx:135, in pandas._libs.index.IndexEngine._get_loc_duplicates()
#
# ...

# %%
df_indexed.iloc[ 0 ]
# Out:
# avg_high                 58.000
# avg_low                  42.000
# record_high              73.000
# record_low               21.000
# avg_precipitation         2.560
# avg_precipitation_new     2.816
# naujas                    1.000
# Name: Dec, dtype: float64

# %%
df_indexed
# Out:
#        avg_high  avg_low  record_high  record_low  avg_precipitation  \
# month
# Dec          58     42.0         73.0          21               2.56
# Jan          58     42.0         74.0          22               2.05
# Feb          61     45.0         78.0          26               3.02
# Mar          65     48.0         84.0          25               2.34
# Nov          64     48.0         84.0          30               1.70
# Apr          67     50.0         92.0          28               1.02
# Oct          73     54.0         96.0          34               0.81
# May          71     53.0         98.0          35               0.48
# Aug          77     59.0        102.0          43               0.03
# Sep          77     57.0        103.0          40               0.17
# Jul          77     58.0        105.0          44               0.00
# Jun          75     56.0        107.0          41               0.11
# ...

# %%
df_indexed.columns = [ 'avg_high', 'avg_low', 'record_high', 'record_low', 'avg_precipitation', 'avg_precipitation_new', 'naujas' ]
# df_indexed.columns = [ 'naujas', 'avg_high', 'avg_low', 'record_high', 'record_low', 'avg_precipitation', 'avg_precipitation_new',  ]
df_indexed
# Out:
#        avg_high  avg_low  record_high  record_low  avg_precipitation  \
# month
# Dec          58     42.0         73.0          21               2.56
# Jan          58     42.0         74.0          22               2.05
# Feb          61     45.0         78.0          26               3.02
# Mar          65     48.0         84.0          25               2.34
# Nov          64     48.0         84.0          30               1.70
# Apr          67     50.0         92.0          28               1.02
# Oct          73     54.0         96.0          34               0.81
# May          71     53.0         98.0          35               0.48
# Aug          77     59.0        102.0          43               0.03
# Sep          77     57.0        103.0          40               0.17
# Jul          77     58.0        105.0          44               0.00
# Jun          75     56.0        107.0          41               0.11
# ...

# %%
df_indexed = df_indexed[ ['naujas', 'avg_low', 'avg_high', 'record_high', 'record_low', 'avg_precipitation', 'avg_precipitation_new'] ]
df_indexed
# Out:
#        naujas  avg_low  avg_high  record_high  record_low  avg_precipitation  \
# month
# Dec         1     42.0        58         73.0          21               2.56
# Jan         1     42.0        58         74.0          22               2.05
# Feb         1     45.0        61         78.0          26               3.02
# Mar         1     48.0        65         84.0          25               2.34
# Nov         1     48.0        64         84.0          30               1.70
# Apr         1     50.0        67         92.0          28               1.02
# Oct         1     54.0        73         96.0          34               0.81
# May         1     53.0        71         98.0          35               0.48
# Aug         1     59.0        77        102.0          43               0.03
# Sep         1     57.0        77        103.0          40               0.17
# Jul         1     58.0        77        105.0          44               0.00
# ...

# %%
df_indexed[ ['record_high', 'avg_high' ] ]
# Out:
#        record_high  avg_high
# month
# Dec           73.0        58
# Jan           74.0        58
# Feb           78.0        61
# Mar           84.0        65
# Nov           84.0        64
# Apr           92.0        67
# Oct           96.0        73
# May           98.0        71
# Aug          102.0        77
# Sep          103.0        77
# Jul          105.0        77
# Jun          107.0        75
# Dec            NaN        58

# %%
df_indexed[ ['record_high', 'avg_high' ] ].sum()
# Out:
# record_high    1096.0
# avg_high        881.0
# dtype: float64

# %%
df_indexed.loc[ :, 'sum_high_avg'] =  df_indexed.loc[ :, ['record_high', 'avg_high' ] ].sum( axis=1 )
df_indexed
# Out:
# c:\Users\Robotux\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\core\indexing.py:1773: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_column(ilocs[0], value, pi)
#        naujas  avg_low  avg_high  record_high  record_low  avg_precipitation  \
# month
# Dec         1     42.0        58         73.0          21               2.56
# Jan         1     42.0        58         74.0          22               2.05
# Feb         1     45.0        61         78.0          26               3.02
# Mar         1     48.0        65         84.0          25               2.34
# Nov         1     48.0        64         84.0          30               1.70
# ...

# %%
df_indexed.dropna()
# Out:
#        naujas  avg_low  avg_high  record_high  record_low  avg_precipitation  \
# month
# Dec         1     42.0        58         73.0          21               2.56
# Jan         1     42.0        58         74.0          22               2.05
# Feb         1     45.0        61         78.0          26               3.02
# Mar         1     48.0        65         84.0          25               2.34
# Nov         1     48.0        64         84.0          30               1.70
# Apr         1     50.0        67         92.0          28               1.02
# Oct         1     54.0        73         96.0          34               0.81
# May         1     53.0        71         98.0          35               0.48
# Aug         1     59.0        77        102.0          43               0.03
# Sep         1     57.0        77        103.0          40               0.17
# Jul         1     58.0        77        105.0          44               0.00
# ...

# %%
df_indexed.loc['Dec', 'avg_low'] = 100
df_indexed
# Out:
#        naujas  avg_low  avg_high  record_high  record_low  avg_precipitation  \
# month
# Dec         1    100.0        58         73.0          21               2.56
# Jan         1     42.0        58         74.0          22               2.05
# Feb         1     45.0        61         78.0          26               3.02
# Mar         1     48.0        65         84.0          25               2.34
# Nov         1     48.0        64         84.0          30               1.70
# Apr         1     50.0        67         92.0          28               1.02
# Oct         1     54.0        73         96.0          34               0.81
# May         1     53.0        71         98.0          35               0.48
# Aug         1     59.0        77        102.0          43               0.03
# Sep         1     57.0        77        103.0          40               0.17
# Jul         1     58.0        77        105.0          44               0.00
# ...

# %%
df_unindexed = df_indexed.reset_index()
df_unindexed
# Out:
#    month  naujas  avg_low  avg_high  record_high  record_low  \
# 0    Dec       1    100.0        58         73.0          21
# 1    Jan       1     42.0        58         74.0          22
# 2    Feb       1     45.0        61         78.0          26
# 3    Mar       1     48.0        65         84.0          25
# 4    Nov       1     48.0        64         84.0          30
# 5    Apr       1     50.0        67         92.0          28
# 6    Oct       1     54.0        73         96.0          34
# 7    May       1     53.0        71         98.0          35
# 8    Aug       1     59.0        77        102.0          43
# 9    Sep       1     57.0        77        103.0          40
# 10   Jul       1     58.0        77        105.0          44
# 11   Jun       1     56.0        75        107.0          41
# 12   Dec       1    100.0        58          NaN          21
#
#     avg_precipitation  avg_precipitation_new  sum_high_avg
# ...

# %%
df_unindexed.loc[ 0, 'avg_low' ] = 42.2
df_unindexed
# Out:
#    month  naujas  avg_low  avg_high  record_high  record_low  \
# 0    Dec       1     42.2        58         73.0          21
# 1    Jan       1     42.0        58         74.0          22
# 2    Feb       1     45.0        61         78.0          26
# 3    Mar       1     48.0        65         84.0          25
# 4    Nov       1     48.0        64         84.0          30
# 5    Apr       1     50.0        67         92.0          28
# 6    Oct       1     54.0        73         96.0          34
# 7    May       1     53.0        71         98.0          35
# 8    Aug       1     59.0        77        102.0          43
# 9    Sep       1     57.0        77        103.0          40
# 10   Jul       1     58.0        77        105.0          44
# 11   Jun       1     56.0        75        107.0          41
# 12   Dec       1    100.0        58          NaN          21
#
#     avg_precipitation  avg_precipitation_new  sum_high_avg
# ...

# %% [markdown]
# ## Groupby

# %%
# df_unindexed.groupby('month')
df_unindexed.groupby('month').sum()
# Out:
#        naujas  avg_low  avg_high  record_high  record_low  avg_precipitation  \
# month
# Apr         1     50.0        67         92.0          28               1.02
# Aug         1     59.0        77        102.0          43               0.03
# Dec         2    142.2       116         73.0          42               5.12
# Feb         1     45.0        61         78.0          26               3.02
# Jan         1     42.0        58         74.0          22               2.05
# Jul         1     58.0        77        105.0          44               0.00
# Jun         1     56.0        75        107.0          41               0.11
# Mar         1     48.0        65         84.0          25               2.34
# May         1     53.0        71         98.0          35               0.48
# Nov         1     48.0        64         84.0          30               1.70
# Oct         1     54.0        73         96.0          34               0.81
# ...

# %%
df_unindexed.groupby('month').mean()
# Out:
#        naujas  avg_low  avg_high  record_high  record_low  avg_precipitation  \
# month
# Apr       1.0     50.0      67.0         92.0        28.0               1.02
# Aug       1.0     59.0      77.0        102.0        43.0               0.03
# Dec       1.0     71.1      58.0         73.0        21.0               2.56
# Feb       1.0     45.0      61.0         78.0        26.0               3.02
# Jan       1.0     42.0      58.0         74.0        22.0               2.05
# Jul       1.0     58.0      77.0        105.0        44.0               0.00
# Jun       1.0     56.0      75.0        107.0        41.0               0.11
# Mar       1.0     48.0      65.0         84.0        25.0               2.34
# May       1.0     53.0      71.0         98.0        35.0               0.48
# Nov       1.0     48.0      64.0         84.0        30.0               1.70
# Oct       1.0     54.0      73.0         96.0        34.0               0.81
# ...

# %% [markdown]
# ## filtering

# %%
df_unindexed[ df_unindexed['record_low'] > 30 ]
# Out:
#    month  naujas  avg_low  avg_high  record_high  record_low  \
# 6    Oct       1     54.0        73         96.0          34
# 7    May       1     53.0        71         98.0          35
# 8    Aug       1     59.0        77        102.0          43
# 9    Sep       1     57.0        77        103.0          40
# 10   Jul       1     58.0        77        105.0          44
# 11   Jun       1     56.0        75        107.0          41
#
#     avg_precipitation  avg_precipitation_new  sum_high_avg
# 6                0.81                  0.891         169.0
# 7                0.48                  0.528         169.0
# 8                0.03                  0.033         179.0
# 9                0.17                  0.187         180.0
# 10               0.00                  0.000         182.0
# 11               0.11                  0.121         182.0

# %%
df_unindexed['record_low'] > 30 # this is called a mask
# Out:
# 0     False
# 1     False
# 2     False
# 3     False
# 4     False
# 5     False
# 6      True
# 7      True
# 8      True
# 9      True
# 10     True
# 11     True
# 12    False
# Name: record_low, dtype: bool

# %%
df_unindexed['groupby_percipitation'] = (df_unindexed['avg_precipitation'] > 1).map({True: 'More than 1', False: 'Less than 1'})
df_unindexed
# Out:
#    month  naujas  avg_low  avg_high  record_high  record_low  \
# 0    Dec       1     42.2        58         73.0          21
# 1    Jan       1     42.0        58         74.0          22
# 2    Feb       1     45.0        61         78.0          26
# 3    Mar       1     48.0        65         84.0          25
# 4    Nov       1     48.0        64         84.0          30
# 5    Apr       1     50.0        67         92.0          28
# 6    Oct       1     54.0        73         96.0          34
# 7    May       1     53.0        71         98.0          35
# 8    Aug       1     59.0        77        102.0          43
# 9    Sep       1     57.0        77        103.0          40
# 10   Jul       1     58.0        77        105.0          44
# 11   Jun       1     56.0        75        107.0          41
# 12   Dec       1    100.0        58          NaN          21
#
#     avg_precipitation  avg_precipitation_new  sum_high_avg  \
# ...

# %%
df_unindexed.groupby('groupby_percipitation').sum()
# Out:
#                        naujas  avg_low  avg_high  record_high  record_low  \
# groupby_percipitation
# Less than 1                 6    337.0       450        611.0         237
# More than 1                 7    375.2       431        485.0         173
#
#                        avg_precipitation  avg_precipitation_new  sum_high_avg
# groupby_percipitation
# Less than 1                         1.60                  1.760        1061.0
# More than 1                        15.25                 16.775         916.0

# %%
df_unindexed
# Out:
#    month  naujas  avg_low  avg_high  record_high  record_low  \
# 0    Dec       1     42.2        58         73.0          21
# 1    Jan       1     42.0        58         74.0          22
# 2    Feb       1     45.0        61         78.0          26
# 3    Mar       1     48.0        65         84.0          25
# 4    Nov       1     48.0        64         84.0          30
# 5    Apr       1     50.0        67         92.0          28
# 6    Oct       1     54.0        73         96.0          34
# 7    May       1     53.0        71         98.0          35
# 8    Aug       1     59.0        77        102.0          43
# 9    Sep       1     57.0        77        103.0          40
# 10   Jul       1     58.0        77        105.0          44
# 11   Jun       1     56.0        75        107.0          41
# 12   Dec       1    100.0        58          NaN          21
#
#     avg_precipitation  avg_precipitation_new  sum_high_avg  \
# ...

# %%
df_unindexed.to_csv('weather.csv')

# %%
df_unindexed.plot()
# Out:
# <AxesSubplot:>

# %%
df_unindexed.plot.hist(bins=12, alpha=0.5)
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
df_unindexed[ ['avg_low', 'avg_high'] ].plot.hist(bins=12, alpha=0.5)
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
df_football = pd.read_csv('LT.csv')
df_football
# Out:
#            date   home_team  away_team  home_score  away_score  \
# 0    1979-07-20  Kyrgyzstan  Lithuania           0           0
# 1    1979-07-22     Georgia  Lithuania           5           0
# 2    1979-07-24  Azerbaijan  Lithuania           0           1
# 3    1979-07-28   Lithuania    Ukraine           0           2
# 4    1979-07-30      Russia  Lithuania           2           0
# ..          ...         ...        ...         ...         ...
# 362  2019-09-10   Lithuania   Portugal           1           5
# 363  2019-10-11     Ukraine  Lithuania           2           0
# 364  2019-10-11     Ukraine  Lithuania           2           0
# 365  2019-10-14   Lithuania     Serbia           1           2
# 366  2019-10-14   Lithuania     Serbia           1           2
#
#                   tourniment     city       country
# 0                   Friendly   Moscow  Soviet Union
# 1                   Friendly   Moscow  Soviet Union
# ...

# %%
df_football.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 367 entries, 0 to 366
# Data columns (total 8 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   date        367 non-null    object
#  1   home_team   367 non-null    object
#  2   away_team   367 non-null    object
#  3   home_score  367 non-null    int64
#  4   away_score  367 non-null    int64
#  5   tourniment  367 non-null    object
#  6   city        367 non-null    object
#  7   country     367 non-null    object
# dtypes: int64(2), object(6)
# memory usage: 23.1+ KB

# %%
import datetime

# df_football[ df_football['date']  > datetime.date(2000, 1, 1)  ] # error
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Input In [112], in <module>
#       1 import datetime
# ----> 3 df_football[ df_football['date']  > datetime.date(2000, 1, 1)  ]
#
# File c:\Users\Robotux\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\core\ops\common.py:69, in _unpack_zerodim_and_defer.<locals>.new_method(self, other)
#      65             return NotImplemented
#      67 other = item_from_zerodim(other)
# ---> 69 return method(self, other)
#
# File c:\Users\Robotux\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\core\arraylike.py:48, in OpsMixin.__gt__(self, other)
#      46 @unpack_zerodim_and_defer("__gt__")
#      47 def __gt__(self, other):
# ---> 48     return self._cmp_method(other, operator.gt)
#
# ...

# %%
df_football[ 'date' ] = pd.to_datetime( df_football['date'], format='%d-%m-%Y' )

# %%
df_football.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 367 entries, 0 to 366
# Data columns (total 8 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   date        367 non-null    datetime64[ns]
#  1   home_team   367 non-null    object
#  2   away_team   367 non-null    object
#  3   home_score  367 non-null    int64
#  4   away_score  367 non-null    int64
#  5   tourniment  367 non-null    object
#  6   city        367 non-null    object
#  7   country     367 non-null    object
# dtypes: datetime64[ns](1), int64(2), object(5)
# memory usage: 23.1+ KB

# %%
df_football[ df_football['date'].dt.date  > datetime.date(2015, 8, 1)  ] # no error
# Out:
#           date  home_team   away_team  home_score  away_score  \
# 287 2015-09-05    Estonia   Lithuania           1           0
# 288 2015-09-05    Estonia   Lithuania           1           0
# 289 2015-09-08  Lithuania  San Marino           2           1
# 290 2015-09-08  Lithuania  San Marino           2           1
# 291 2015-10-09   Slovenia   Lithuania           1           1
# ..         ...        ...         ...         ...         ...
# 362 2019-09-10  Lithuania    Portugal           1           5
# 363 2019-10-11    Ukraine   Lithuania           2           0
# 364 2019-10-11    Ukraine   Lithuania           2           0
# 365 2019-10-14  Lithuania      Serbia           1           2
# 366 2019-10-14  Lithuania      Serbia           1           2
#
#                   tourniment       city    country
# 287  UEFA Euro qualification    Tallinn    Estonia
# 288  UEFA Euro qualification    Tallinn    Estonia
# 289  UEFA Euro qualification    Vilnius  Lithuania
# ...

# %%
df_football
# Out:
#           date   home_team  away_team  home_score  away_score  \
# 0   1979-07-20  Kyrgyzstan  Lithuania           0           0
# 1   1979-07-22     Georgia  Lithuania           5           0
# 2   1979-07-24  Azerbaijan  Lithuania           0           1
# 3   1979-07-28   Lithuania    Ukraine           0           2
# 4   1979-07-30      Russia  Lithuania           2           0
# ..         ...         ...        ...         ...         ...
# 362 2019-09-10   Lithuania   Portugal           1           5
# 363 2019-10-11     Ukraine  Lithuania           2           0
# 364 2019-10-11     Ukraine  Lithuania           2           0
# 365 2019-10-14   Lithuania     Serbia           1           2
# 366 2019-10-14   Lithuania     Serbia           1           2
#
#                   tourniment     city       country
# 0                   Friendly   Moscow  Soviet Union
# 1                   Friendly   Moscow  Soviet Union
# 2                   Friendly   Moscow  Soviet Union
# ...

# %%
df_football[ df_football['home_team'] == 'Lithuania' ]
# Out:
#           date  home_team away_team  home_score  away_score  \
# 3   1979-07-28  Lithuania   Ukraine           0           2
# 8   1991-11-15  Lithuania   Estonia           4           1
# 9   1991-11-17  Lithuania    Latvia           1           1
# 17  1992-09-02  Lithuania   Georgia           1           0
# 18  1992-09-23  Lithuania   Denmark           0           0
# ..         ...        ...       ...         ...         ...
# 360 2019-09-07  Lithuania   Ukraine           0           3
# 361 2019-09-10  Lithuania  Portugal           1           5
# 362 2019-09-10  Lithuania  Portugal           1           5
# 365 2019-10-14  Lithuania    Serbia           1           2
# 366 2019-10-14  Lithuania    Serbia           1           2
#
#                        tourniment      city       country
# 3                        Friendly    Moscow  Soviet Union
# 8                      Baltic Cup  Klaipeda     Lithuania
# 9                      Baltic Cup  Kretinga     Lithuania
# ...

# %%
df_football[ (df_football['home_team'] == 'Lithuania') & (df_football['home_score'] > 0) ] # and
# Out:
#           date  home_team   away_team  home_score  away_score  \
# 8   1991-11-15  Lithuania     Estonia           4           1
# 9   1991-11-17  Lithuania      Latvia           1           1
# 17  1992-09-02  Lithuania     Georgia           1           0
# 20  1992-10-28  Lithuania      Latvia           1           1
# 26  1993-04-14  Lithuania     Albania           3           1
# ..         ...        ...         ...         ...         ...
# 356 2019-06-07  Lithuania  Luxembourg           1           1
# 361 2019-09-10  Lithuania    Portugal           1           5
# 362 2019-09-10  Lithuania    Portugal           1           5
# 365 2019-10-14  Lithuania      Serbia           1           2
# 366 2019-10-14  Lithuania      Serbia           1           2
#
#                        tourniment      city    country
# 8                      Baltic Cup  Klaipeda  Lithuania
# 9                      Baltic Cup  Kretinga  Lithuania
# ...

# %%
print(df_football)
# Out:
#           date   home_team  away_team  home_score  away_score  \
# 0   1979-07-20  Kyrgyzstan  Lithuania           0           0
# 1   1979-07-22     Georgia  Lithuania           5           0
# 2   1979-07-24  Azerbaijan  Lithuania           0           1
# 3   1979-07-28   Lithuania    Ukraine           0           2
# 4   1979-07-30      Russia  Lithuania           2           0
# ..         ...         ...        ...         ...         ...
# 362 2019-09-10   Lithuania   Portugal           1           5
# 363 2019-10-11     Ukraine  Lithuania           2           0
# 364 2019-10-11     Ukraine  Lithuania           2           0
# 365 2019-10-14   Lithuania     Serbia           1           2
# 366 2019-10-14   Lithuania     Serbia           1           2
#
#                   tourniment     city       country
# 0                   Friendly   Moscow  Soviet Union
# 1                   Friendly   Moscow  Soviet Union
# 2                   Friendly   Moscow  Soviet Union
# ...

# %%
df_football['home_team'] == 'Lithuania'
# Out:
# 0      False
# 1      False
# 2      False
# 3       True
# 4      False
#        ...
# 362     True
# 363    False
# 364    False
# 365     True
# 366     True
# Name: home_team, Length: 367, dtype: bool

# %%
df_football['home_score'] > 0
# Out:
# 0      False
# 1       True
# 2      False
# 3      False
# 4       True
#        ...
# 362     True
# 363     True
# 364     True
# 365     True
# 366     True
# Name: home_score, Length: 367, dtype: bool

# %%
# Atitikmenys tikrinant panariui - Bitwise operator
# and = &
# or = | 
# not = ~
# in = .isin()

# %%
df_football
# Out:
#           date   home_team  away_team  home_score  away_score  \
# 0   1979-07-20  Kyrgyzstan  Lithuania           0           0
# 1   1979-07-22     Georgia  Lithuania           5           0
# 2   1979-07-24  Azerbaijan  Lithuania           0           1
# 3   1979-07-28   Lithuania    Ukraine           0           2
# 4   1979-07-30      Russia  Lithuania           2           0
# ..         ...         ...        ...         ...         ...
# 362 2019-09-10   Lithuania   Portugal           1           5
# 363 2019-10-11     Ukraine  Lithuania           2           0
# 364 2019-10-11     Ukraine  Lithuania           2           0
# 365 2019-10-14   Lithuania     Serbia           1           2
# 366 2019-10-14   Lithuania     Serbia           1           2
#
#                   tourniment     city       country
# 0                   Friendly   Moscow  Soviet Union
# 1                   Friendly   Moscow  Soviet Union
# 2                   Friendly   Moscow  Soviet Union
# ...

# %%
df_football[ (df_football['city'].isin( ['Vilnius', 'Kaunas'] ) ) & (df_football['home_score'] - df_football['away_score'] > 2 ) ] #
# Out:
#           date  home_team   away_team  home_score  away_score  \
# 37  1994-07-29  Lithuania     Estonia           3           0
# 53  1995-10-11  Lithuania     Estonia           5           0
# 64  1996-11-03  Lithuania   Indonesia           4           0
# 144 2004-09-08  Lithuania  San Marino           4           0
# 213 2011-08-10  Lithuania     Armenia           3           0
# 214 2011-08-10  Lithuania     Armenia           3           0
#
#                        tourniment     city    country
# 37                     Baltic Cup  Vilnius  Lithuania
# 53        UEFA Euro qualification  Vilnius  Lithuania
# 64                       Friendly  Vilnius  Lithuania
# 144  FIFA World Cup qualification   Kaunas  Lithuania
# 213                      Friendly   Kaunas  Lithuania
# 214                      Friendly   Kaunas  Lithuania

# %%
# # Kiek ivarciu lietuviai imuse ir praleido zaisdami skirtinguose cempionatuose, zaisdami isvykoje?
# 1. Atsifiltruoti, ten kur lietuviai zaide isvykoje
# 2. Sugrupuoti pagal tournamenta
# 4. Gale prideti .sum()
